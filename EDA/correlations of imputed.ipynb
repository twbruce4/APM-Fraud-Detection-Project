# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

training = pd.read_csv('train_transaction.csv')
# Out:
#         TransactionID  isFraud  TransactionDT  TransactionAmt  ProductCD  \
# 0               False    False          False           False      False
# 1               False    False          False           False      False
# 2               False    False          False           False      False
# 3               False    False          False           False      False
# 4               False    False          False           False      False
# ...               ...      ...            ...             ...        ...
# 590535          False    False          False           False      False
# 590536          False    False          False           False      False
# 590537          False    False          False           False      False
# 590538          False    False          False           False      False
# 590539          False    False          False           False      False
#
#         card1  card2  card3  card4  card5  ...   V330   V331   V332   V333  \
# ...

# %%
# consider only columns with less than 1% NaN
low_null_columns = (training.isnull().sum()/len(training)*100) < 1
low_nulls = []
index=0
for column in low_null_columns:
    if column == True:
        low_null_columns.index[index]
        low_nulls.append(low_null_columns.index[index])
    index += 1
training_imputed = training.loc[:, low_nulls]
training_imputed = training_imputed.dropna()
training_imputed.shape
# Out:
# (584843, 111)

# %%
correlated = set()
correlations = training_imputed.corr()
# mask = training_imputed['isFraud'] == 1
# fraudulents = training_imputed[mask]
# corrs = fraudulents.corr()

# %%
pd.set_option('display.max_rows', 500)
cor_target = abs(correlations["isFraud"])
relevant_features = cor_target[cor_target>0.5]
cor_target.sort_values(ascending=False)
# Out:
# isFraud           1.000000
# card3             0.155283
# V123              0.139346
# V302              0.133547
# V304              0.132130
# V303              0.126049
# V111              0.122464
# V113              0.116807
# V283              0.113227
# V125              0.113142
# V112              0.105934
# V282              0.104967
# V108              0.097526
# V114              0.096913
# V110              0.082206
# V116              0.081312
# V124              0.077537
# V281              0.072929
# D1                0.068643
# V292              0.067262
# V291              0.063288
# V109              0.061452
# V115              0.057573
# V117              0.050236
# V119              0.048985
# V315              0.047745
# V290              0.045916
# V289              0.042583
# V313              0.041451
# V118              0.041236
# V312              0.036925
# C2                0.036588
# V314              0.036566
# V284              0.035578
# ...

# %%
relevant_features
# Out:
# isFraud    1.0
# Name: isFraud, dtype: float64
